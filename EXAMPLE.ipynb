# %%
from MLSpy import MLSpy
import glob
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %load_ext autotime
# Out:
# time: 266 µs (started: 2023-01-28 16:28:46 +05:30)

# %%
#time has 3 options
# 1. day: only the daytime swaths
# 2. night: only night time path
# 3. none: combined (day+night)

a = MLSpy.mls_o3_profile('/media/user/8A368DA3368D913D/MLS/MLS-Aura_L2GP-O3_v05-01-c01_2005d333.he5', time='day')
a.isel(levs=0).plot(robust=True, cmap='jet')
# Out:
# 261.0157
# 215.4435
# 177.8279
# 146.7799
# 121.1528
# 100
# 82.54042
# 68.1292
# 56.23413
# 46.41589
# 38.31187
# 31.62278
# 26.10157
# 21.54435
# 17.78279
# 14.67799
# 12.11528
# 10
# 8.254042
# 6.812921
# 5.623413
# 4.641589
# 3.831187
# 3.162278
# 2.610157
# 2.154435
# 1.778279
# 1.467799
# 1.211528
# 1
# 0.6812921
# 0.4641589
# 0.3162278
# 0.2154435
# 0.1467799
# 0.1
# 0.04641589
# 0.02154435
# time: 10.5 s (started: 2023-01-28 16:35:32 +05:30)

# %%
a = MLSpy.mls_o3_profile('/media/user/8A368DA3368D913D/MLS/MLS-Aura_L2GP-O3_v05-01-c01_2005d333.he5', time='night')
a.isel(levs=0).plot(robust=True, cmap='jet')
# Out:
# 261.0157
# 215.4435
# 177.8279
# 146.7799
# 121.1528
# 100
# 82.54042
# 68.1292
# 56.23413
# 46.41589
# 38.31187
# 31.62278
# 26.10157
# 21.54435
# 17.78279
# 14.67799
# 12.11528
# 10
# 8.254042
# 6.812921
# 5.623413
# 4.641589
# 3.831187
# 3.162278
# 2.610157
# 2.154435
# 1.778279
# 1.467799
# 1.211528
# 1
# 0.6812921
# 0.4641589
# 0.3162278
# 0.2154435
# 0.1467799
# 0.1
# 0.04641589
# 0.02154435
# time: 10.4 s (started: 2023-01-28 16:35:44 +05:30)

# %%
a = MLSpy.mls_o3_profile('/media/user/8A368DA3368D913D/MLS/MLS-Aura_L2GP-O3_v05-01-c01_2005d333.he5', time='none')
a.isel(levs=0).plot(robust=True, cmap='jet')
# Out:
# 261.0157
# 215.4435
# 177.8279
# 146.7799
# 121.1528
# 100
# 82.54042
# 68.1292
# 56.23413
# 46.41589
# 38.31187
# 31.62278
# 26.10157
# 21.54435
# 17.78279
# 14.67799
# 12.11528
# 10
# 8.254042
# 6.812921
# 5.623413
# 4.641589
# 3.831187
# 3.162278
# 2.610157
# 2.154435
# 1.778279
# 1.467799
# 1.211528
# 1
# 0.6812921
# 0.4641589
# 0.3162278
# 0.2154435
# 0.1467799
# 0.1
# 0.04641589
# 0.02154435
# time: 10.4 s (started: 2023-01-28 16:36:27 +05:30)
